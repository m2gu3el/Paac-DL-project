# %% [markdown]
# <a href="https://colab.research.google.com/github/m2gu3el/Paac-DL-project/blob/main/Paac_AE%20and%20VAE%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, models, Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout,Input, Lambda, Reshape, Conv2DTranspose, GlobalAvgPool2D
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
import tensorflow._api.v2.compat.v1 as tf
tf.disable_v2_behavior()

# %%
# !pip install astroNN
# Out:
# Requirement already satisfied: astroNN in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from astroNN) (1.23.5)
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from astroNN) (5.3.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from astroNN) (3.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from astroNN) (3.7.1)
# Requirement already satisfied: astroquery in /usr/local/lib/python3.10/dist-packages (from astroNN) (0.4.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from astroNN) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from astroNN) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from astroNN) (4.66.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from astroNN) (23.2)
# Requirement already satisfied: tensorflow>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from astroNN) (2.14.0)
# Requirement already satisfied: tensorflow-probability>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from astroNN) (0.22.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (1.59.3)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->astroNN) (2.14.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.19.0->astroNN) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.19.0->astroNN) (2.2.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.19.0->astroNN) (0.1.8)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy->astroNN) (2.0.1.1)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy->astroNN) (6.0.1)
# Requirement already satisfied: requests>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from astroquery->astroNN) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.3.2 in /usr/local/lib/python3.10/dist-packages (from astroquery->astroNN) (4.11.2)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery->astroNN) (1.1)
# Requirement already satisfied: keyring>=4.0 in /usr/lib/python3/dist-packages (from astroquery->astroNN) (23.5.0)
# Requirement already satisfied: pyvo>=1.1 in /usr/local/lib/python3.10/dist-packages (from astroquery->astroNN) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->astroNN) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->astroNN) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->astroNN) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->astroNN) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->astroNN) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->astroNN) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->astroNN) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->astroNN) (2023.3.post1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->astroNN) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->astroNN) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->astroNN) (3.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.11.0->astroNN) (0.42.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.3.2->astroquery->astroNN) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery->astroNN) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery->astroNN) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery->astroNN) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery->astroNN) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.4.3->astroquery->astroNN) (2023.11.17)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow>=2.11.0->astroNN) (3.2.2)

# %%
from sklearn.model_selection import train_test_split
from astroNN.models import Galaxy10CNN
from astroNN.datasets import load_galaxy10sdss
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
images, labels = load_galaxy10sdss()
images_train, images_test, labels_train, labels_test = train_test_split(
     images, labels, test_size=0.1, random_state=42)

images_train.size, images_test.size
# Out:
# /root/.astroNN/datasets/Galaxy10.h5 was found!
# (280032498, 31122657)

# %%
images_train = images.astype(np.float32)/255
images_test = images.astype(np.float32)/255

# %%
img_width  = images.shape[1]
img_height = images.shape[2]
img_width, img_height
# Out:
# (69, 69)

# %%
cifar10 = tf.keras.datasets.cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
y_train=y_train.flatten()
y_test=y_test.flatten()

# %%
img_width  = X_train.shape[1]
img_height = X_train.shape[2]
img_width, img_height
# Out:
# (32, 32)

# %%
plt.figure(figsize=(12,5))
plt.subplot(221)
plt.imshow(X_train[4][:,:,:])

plt.subplot(222)
plt.imshow(X_train[6][:,:,:])

plt.subplot(223)
plt.imshow(X_train[8][:,:,:])

plt.subplot(224)
plt.imshow(X_train[10][:,:,:])

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 10)  # one-hot encode the labels
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ###Variational Autoencoder

# %% [markdown]
# -> Instead of directly producing a coding
# for a given input, the encoder produces a mean coding μ and a standard
# deviation γ. The actual coding is then sampled randomly from a Gaussian
# distribution with mean μ and standard deviation γ. After that the decoder
# decodes the sampled coding normally.

# %% [markdown]
# ### For Galaxy10

# %% [markdown]
# ![Screenshot 2023-12-16 232931.png](data:image/png;base64,...)

# %% [markdown]
# # Above is a representation of the structure of a Variational Autoencoder.
# 1. Input layer
# 2. Hidden layers- Conv2d and Dense
# 3. Dense layers splitting into - μ and γ i.e mean and variance
# 4. Sampling using gausian distribution- z= μ + eγ (encoder ends with z, μ , γ as outputs)
# 5. Hidden layers- Conv2dtranspose and dense.
# 6. Final output

# %%
class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return tf.random.normal(tf.shape(log_var)) * tf.exp(log_var / 2) + mean

# %%
codings_size = 2

inputs = Input(shape=(69,69,3), name='encoder_input')
x = Conv2D(32, 3, padding='same', activation='relu')(inputs)
x = Conv2D(64, 3, padding='same', activation='relu',strides=(3, 3))(x)
x = Conv2D(64, 3, padding='same', activation='relu')(x)
x = Conv2D(64, 3, padding='same', activation='relu')(x)

conv_shape=tf.shape(x)

x = Flatten()(x)
x = Dense(150, activation="relu")(x)
x = Dense(100, activation="relu")(x)
codings_mean = Dense(codings_size)(x)  # μ
codings_log_var =Dense(codings_size)(x)  # γ
codings = Sampling()([codings_mean, codings_log_var]) # z
variational_encoder = models.Model(
    inputs=[inputs], outputs=[codings_mean, codings_log_var, codings])

# %%
print(variational_encoder.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  encoder_input (InputLayer)  [(None, 69, 69, 3)]          0         []
#
#  conv2d_4 (Conv2D)           (None, 69, 69, 32)           896       ['encoder_input[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 23, 23, 64)           18496     ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 23, 23, 64)           36928     ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 23, 23, 64)           36928     ['conv2d_6[0][0]']
#
#  flatten_1 (Flatten)         (None, 33856)                0         ['conv2d_7[0][0]']
#
#  dense_5 (Dense)             (None, 150)                  5078550   ['flatten_1[0][0]']
#
#  dense_6 (Dense)             (None, 100)                  15100     ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 2)                    202       ['dense_6[0][0]']
#
#  dense_8 (Dense)             (None, 2)                    202       ['dense_6[0][0]']
#
#  sampling_1 (Sampling)       (None, 2)                    0         ['dense_7[0][0]',
#                                                                      'dense_8[0][0]']
#
# ==================================================================================================
# Total params: 5187302 (19.79 MB)
# Trainable params: 5187302 (19.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
decoder_inputs = Input(shape=(codings_size,), name='decoder_input')

x = Dense(23*23*64, activation='relu')(decoder_inputs)
x = Reshape((23,23,64))(x)

x=Conv2DTranspose(64,3, activation='relu', padding='same', strides=(3,3))(x)
x=Conv2DTranspose(3 ,3, activation='sigmoid', padding='same' )(x)              # Sigmoid for RGB images

variational_decoder = tf.keras.Model(inputs=[decoder_inputs], outputs=x)

# %%
print(variational_decoder.summary())
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_9 (Dense)             (None, 33856)             101568
#
#  reshape_1 (Reshape)         (None, 23, 23, 64)        0
#
#  conv2d_transpose_2 (Conv2D  (None, 69, 69, 64)        36928
#  Transpose)
#
#  conv2d_transpose_3 (Conv2D  (None, 69, 69, 3)         1731
#  Transpose)
#
# =================================================================
# Total params: 140227 (547.76 KB)
# Trainable params: 140227 (547.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
_, _, codings = variational_encoder(inputs)
reconstructions = variational_decoder(codings)
variational_ae = tf.keras.Model(inputs=[inputs], outputs=[reconstructions]) # Combining encoder and decoder to form a VAE

# %% [markdown]
# # Formula for the latent loss in a variantional autoencoder
# -> Here n is the coding size or latent dimensions which is 2

# %% [markdown]
# ![Screenshot 2023-12-16 233311.png](data:image/png;base64,...)

# %%
latent_loss = -0.5 * tf.reduce_sum(
    1 + codings_log_var - tf.exp(codings_log_var) - tf.square(codings_mean),
    axis=-1)
variational_ae.add_loss(tf.reduce_mean(latent_loss) / (69*69*3)) #  we divide the result by 69*69*3 to ensure it has the appropriate scale compared to the reconstruction loss

# %%
variational_ae.compile(loss="mse", optimizer="nadam")
history = variational_ae.fit(images_train, images_train, epochs=25, batch_size=128, validation_data=(images_test, images_test))
# Out:
# Train on 21785 samples, validate on 21785 samples
# Epoch 1/25
# 21785/21785 [==============================] - 21s 944us/sample - loss: 2.9688 - val_loss: 0.0041
# Epoch 2/25
# 21785/21785 [==============================] - 17s 783us/sample - loss: 0.0039 - val_loss: 0.0037
# Epoch 3/25
# 21785/21785 [==============================] - 16s 754us/sample - loss: 0.0035 - val_loss: 0.0033
# Epoch 4/25
# 21785/21785 [==============================] - 17s 758us/sample - loss: 0.0033 - val_loss: 0.0033
# Epoch 5/25
# 21785/21785 [==============================] - 17s 765us/sample - loss: 0.0032 - val_loss: 0.0031
# Epoch 6/25
# 21785/21785 [==============================] - 17s 766us/sample - loss: 0.0031 - val_loss: 0.0033
# Epoch 7/25
# 21785/21785 [==============================] - 18s 827us/sample - loss: 0.0030 - val_loss: 0.0029
# Epoch 8/25
# 21785/21785 [==============================] - 17s 768us/sample - loss: 0.0029 - val_loss: 0.0029
# Epoch 9/25
# 21785/21785 [==============================] - 17s 769us/sample - loss: 0.0029 - val_loss: 0.0029
# Epoch 10/25
# 21785/21785 [==============================] - 18s 807us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 11/25
# 21785/21785 [==============================] - 19s 855us/sample - loss: 0.0028 - val_loss: 0.0028
# Epoch 12/25
# 21785/21785 [==============================] - 17s 769us/sample - loss: 0.0028 - val_loss: 0.0028
# Epoch 13/25
# 21785/21785 [==============================] - 17s 768us/sample - loss: 0.0028 - val_loss: 0.0028
# Epoch 14/25
# 21785/21785 [==============================] - 17s 782us/sample - loss: 0.0028 - val_loss: 0.0028
# Epoch 15/25
# 21785/21785 [==============================] - 17s 768us/sample - loss: 0.0028 - val_loss: 0.0027
# Epoch 16/25
# 21785/21785 [==============================] - 17s 781us/sample - loss: 0.0027 - val_loss: 0.0029
# Epoch 17/25
# 21785/21785 [==============================] - 17s 768us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 18/25
# 21785/21785 [==============================] - 17s 771us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 19/25
# 21785/21785 [==============================] - 17s 770us/sample - loss: 0.0027 - val_loss: 0.0028
# Epoch 20/25
# 21785/21785 [==============================] - 17s 771us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 21/25
# 21785/21785 [==============================] - 17s 772us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 22/25
# 21785/21785 [==============================] - 17s 775us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 23/25
# 21785/21785 [==============================] - 17s 771us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 24/25
# 21785/21785 [==============================] - 17s 766us/sample - loss: 0.0027 - val_loss: 0.0027
# Epoch 25/25
# 21785/21785 [==============================] - 17s 768us/sample - loss: 0.0027 - val_loss: 0.0027

# %% [markdown]
# # Plotting results of VAE for Galaxy10

# %%
reconstructed_images = variational_ae.predict(images_test)


indices_to_visualize = np.random.choice(len(images_test), size=5, replace=False)

# Plot the original and reconstructed images
plt.figure(figsize=(15, 5))
for i, idx in enumerate(indices_to_visualize):

    plt.subplot(2, 5, i + 1)
    plt.imshow(images_test[idx])
    plt.title('Original')
    plt.axis('off')


    plt.subplot(2, 5, i + 6)
    plt.imshow(reconstructed_images[idx])
    plt.title('Reconstructed')
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.

# %% [markdown]
# ### For CIFAR10

# %%
class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return tf.random.normal(tf.shape(log_var)) * tf.exp(log_var / 2) + mean

# %%
codings_size = 2

inputs2 = Input(shape=(32,32,3), name='encoder_input')
x = Conv2D(32, 3, padding='same', activation='relu')(inputs2)
x = Conv2D(64, 3, padding='same', activation='relu',strides=(2, 2))(x)
x = Conv2D(64, 3, padding='same', activation='relu')(x)
x = Conv2D(64, 3, padding='same', activation='relu')(x)

conv_shape2=tf.shape(x)

x = Flatten()(x)
x = Dense(150, activation="relu")(x)
x = Dense(100, activation="relu")(x)
codings_mean2 = Dense(codings_size)(x)  # μ
codings_log_var2 =Dense(codings_size)(x)  # γ
codings2 = Sampling()([codings_mean2, codings_log_var2]) # z
variational_encoder2 = models.Model(
    inputs=[inputs2], outputs=[codings_mean2, codings_log_var2, codings2])

# %%
print(variational_encoder2.summary())
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  encoder_input (InputLayer)  [(None, 32, 32, 3)]          0         []
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)           896       ['encoder_input[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)           18496     ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)           36928     ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)           36928     ['conv2d_10[0][0]']
#
#  flatten_2 (Flatten)         (None, 16384)                0         ['conv2d_11[0][0]']
#
#  dense_10 (Dense)            (None, 150)                  2457750   ['flatten_2[0][0]']
#
#  dense_11 (Dense)            (None, 100)                  15100     ['dense_10[0][0]']
#
#  dense_12 (Dense)            (None, 2)                    202       ['dense_11[0][0]']
#
#  dense_13 (Dense)            (None, 2)                    202       ['dense_11[0][0]']
#
#  sampling_2 (Sampling)       (None, 2)                    0         ['dense_12[0][0]',
#                                                                      'dense_13[0][0]']
#
# ==================================================================================================
# Total params: 2566502 (9.79 MB)
# Trainable params: 2566502 (9.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
decoder_inputs2 = Input(shape=(codings_size,))
x = Dense(16*16*64, activation='relu')(decoder_inputs2)
x = tf.keras.layers.Reshape((16,16,64))(x)
x=Conv2DTranspose(32,3, activation='relu', padding='same', strides=(2,2))(x)
x=Conv2DTranspose( 3 ,3, activation='sigmoid', padding='same' )(x)
variational_decoder2 = tf.keras.Model(inputs=[decoder_inputs2], outputs=x)

# %%
_, _, codings2 = variational_encoder2(inputs2)
reconstructions2 = variational_decoder2(codings2)
variational_ae2 = tf.keras.Model(inputs=[inputs2], outputs=[reconstructions2]) # Combining encoder and decoder to form a VAE

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
latent_loss2 = -0.5 * tf.reduce_sum(
    1 + codings_log_var2 - tf.exp(codings_log_var2) - tf.square(codings_mean2),
    axis=-1)
variational_ae2.add_loss(tf.reduce_mean(latent_loss2) /(32*32*3)) #  we divide the result by 32*32*3 to ensure it has the appropriate scale compared to the reconstruction loss

# %%
variational_ae2.compile(loss="mse", optimizer="nadam")
history = variational_ae2.fit(X_train, X_train, epochs=25, batch_size=128,
                             validation_data=(X_test, X_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 14s 282us/sample - loss: 0.0456 - val_loss: 0.0400
# Epoch 2/25
# 50000/50000 [==============================] - 12s 250us/sample - loss: 0.0391 - val_loss: 0.0383
# Epoch 3/25
# 50000/50000 [==============================] - 12s 249us/sample - loss: 0.0386 - val_loss: 0.0382
# Epoch 4/25
# 50000/50000 [==============================] - 12s 249us/sample - loss: 0.0384 - val_loss: 0.0382
# Epoch 5/25
# 50000/50000 [==============================] - 12s 247us/sample - loss: 0.0382 - val_loss: 0.0380
# Epoch 6/25
# 50000/50000 [==============================] - 12s 247us/sample - loss: 0.0380 - val_loss: 0.0377
# Epoch 7/25
# 50000/50000 [==============================] - 12s 244us/sample - loss: 0.0379 - val_loss: 0.0376
# Epoch 8/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0377 - val_loss: 0.0375
# Epoch 9/25
# 50000/50000 [==============================] - 13s 256us/sample - loss: 0.0378 - val_loss: 0.0377
# Epoch 10/25
# 50000/50000 [==============================] - 12s 250us/sample - loss: 0.0376 - val_loss: 0.0371
# Epoch 11/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0375 - val_loss: 0.0387
# Epoch 12/25
# 50000/50000 [==============================] - 12s 246us/sample - loss: 0.0374 - val_loss: 0.0371
# Epoch 13/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0374 - val_loss: 0.0377
# Epoch 14/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0373 - val_loss: 0.0370
# Epoch 15/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0371 - val_loss: 0.0604
# Epoch 16/25
# 50000/50000 [==============================] - 12s 250us/sample - loss: 0.0373 - val_loss: 0.0368
# Epoch 17/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0370 - val_loss: 0.0367
# Epoch 18/25
# 50000/50000 [==============================] - 12s 247us/sample - loss: 0.0369 - val_loss: 0.0366
# Epoch 19/25
# 50000/50000 [==============================] - 12s 246us/sample - loss: 0.0370 - val_loss: 0.0390
# Epoch 20/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0371 - val_loss: 0.0369
# Epoch 21/25
# 50000/50000 [==============================] - 13s 251us/sample - loss: 0.0373 - val_loss: 0.0368
# Epoch 22/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0368 - val_loss: 0.0367
# Epoch 23/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0370 - val_loss: 0.0380
# Epoch 24/25
# 50000/50000 [==============================] - 13s 251us/sample - loss: 0.0370 - val_loss: 0.0382
# Epoch 25/25
# 50000/50000 [==============================] - 12s 248us/sample - loss: 0.0370 - val_loss: 0.0388

# %% [markdown]
# # Ploting results of VAE for CIFAR10

# %%
reconstructed_images2 = variational_ae2.predict(X_test)

indices_to_visualize = np.random.choice(len(X_test), size=5, replace=False)

plt.figure(figsize=(15, 5))
for i, idx in enumerate(indices_to_visualize):

    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[idx])
    plt.title('Original')
    plt.axis('off')


    plt.subplot(2, 5, i + 6)
    plt.imshow(reconstructed_images2[idx])
    plt.title('Reconstructed')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Simple convolutional Autoencoder

# %% [markdown]
# -> Convolutional autoencoders are better suited for images as compared simple dense autoencoders.

# %% [markdown]
# ![Screenshot 2023-12-16 233954.png](data:image/png;base64,...)

# %% [markdown]
# # Above is a representation of the structure of a simple convolutional Autoencoder.
# 1. Input layer
# 2. Hidden layers- Conv2d and MaxPooling
# 3. Global pooling average layer (encoder ends and decoder starts on the next step)
# 4. Hidden layers- Conv2dtranspose and dense and reshape
# 5. Final output

# %% [markdown]
# ### For galaxy10

# %%
conv_encoder = tf.keras.Sequential([
    Conv2D(16, 3, padding="same", activation="relu", input_shape=(69, 69, 3)),
    MaxPooling2D(pool_size=2),
    Conv2D(32, 3, padding="same", activation="relu"),
    MaxPooling2D(pool_size=2),
    Conv2D(64, 3, padding="same", activation="relu"),
    MaxPooling2D(pool_size=2),
    Conv2D(30, 3, padding="same", activation="relu"),
    GlobalAvgPool2D()
])


conv_decoder = tf.keras.Sequential([
    Input(shape=(30,)),
    Dense(23*23*64, activation="relu"),
    Reshape((23, 23, 64)),
    Conv2DTranspose(64, 3, strides=3, activation="relu", padding="same"),
    Conv2DTranspose(3, 3, strides=1, activation="sigmoid", padding="same"),  # Use sigmoid for RGB images
])

# %%
print(conv_encoder.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 69, 69, 16)        448
#
#  max_pooling2d (MaxPooling2  (None, 34, 34, 16)        0
#  D)
#
#  conv2d_13 (Conv2D)          (None, 34, 34, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 17, 17, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 30)          17310
#
#  global_average_pooling2d (  (None, 30)                0
#  GlobalAveragePooling2D)
#
# =================================================================
# Total params: 40894 (159.74 KB)
# Trainable params: 40894 (159.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
print(conv_decoder.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 33856)             1049536
#
#  reshape_3 (Reshape)         (None, 23, 23, 64)        0
#
#  conv2d_transpose_6 (Conv2D  (None, 69, 69, 64)        36928
#  Transpose)
#
#  conv2d_transpose_7 (Conv2D  (None, 69, 69, 3)         1731
#  Transpose)
#
# =================================================================
# Total params: 1088195 (4.15 MB)
# Trainable params: 1088195 (4.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Combining Encoder and decoder to make an autoencoder
conv_ae = Sequential([conv_encoder, conv_decoder])

# %%
conv_ae.compile(optimizer='nadam', loss='mse')

# %%
conv_ae.fit(images_train, images_train, epochs=10, validation_data=(images_test, images_test))
# Out:
# Train on 21785 samples, validate on 21785 samples
# Epoch 1/10
# 21785/21785 [==============================] - 15s 678us/sample - loss: 0.0065 - val_loss: 0.0030
# Epoch 2/10
# 21785/21785 [==============================] - 13s 608us/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 3/10
# 21785/21785 [==============================] - 13s 614us/sample - loss: 0.0026 - val_loss: 0.0024
# Epoch 4/10
# 21785/21785 [==============================] - 13s 610us/sample - loss: 0.0022 - val_loss: 0.0020
# Epoch 5/10
# 21785/21785 [==============================] - 14s 620us/sample - loss: 0.0019 - val_loss: 0.0018
# Epoch 6/10
# 21785/21785 [==============================] - 13s 616us/sample - loss: 0.0017 - val_loss: 0.0016
# Epoch 7/10
# 21785/21785 [==============================] - 13s 613us/sample - loss: 0.0015 - val_loss: 0.0014
# Epoch 8/10
# 21785/21785 [==============================] - 13s 614us/sample - loss: 0.0014 - val_loss: 0.0014
# Epoch 9/10
# 21785/21785 [==============================] - 14s 653us/sample - loss: 0.0014 - val_loss: 0.0013
# Epoch 10/10
# 21785/21785 [==============================] - 14s 622us/sample - loss: 0.0013 - val_loss: 0.0012

# %%
# Plotting original and reconstructed images
new_images = conv_ae.predict(images_test)

indices_to_visualize = np.random.choice(len(images_test), size=5, replace=False)


plt.figure(figsize=(15, 5))
for i, idx in enumerate(indices_to_visualize):

    plt.subplot(2, 5, i + 1)
    plt.imshow(images_test[idx])
    plt.title('Original')
    plt.axis('off')


    plt.subplot(2, 5, i + 6)
    plt.imshow(new_images[idx])
    plt.title('new')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### For Cifar10

# %%
conv_encoder2 = tf.keras.Sequential([
    Conv2D(16, 3, padding="same", activation="relu", input_shape=(32, 32, 3)),
    MaxPooling2D(pool_size=2),
    Conv2D(32, 3, padding="same", activation="relu"),
    MaxPooling2D(pool_size=2),
    Conv2D(64, 3, padding="same", activation="relu"),
    MaxPooling2D(pool_size=2),
    Conv2D(30, 3, padding="same", activation="relu"),
    GlobalAvgPool2D()
])

conv_decoder2 = tf.keras.Sequential([
    Input(shape=(30,)),
    Dense(16*16*64, activation="relu"),
    Reshape((16, 16, 64)),
    Conv2DTranspose(64, 3, strides=2, activation="relu", padding="same"),
    Conv2DTranspose(3, 3, strides=1, activation="sigmoid", padding="same"),  # Use sigmoid for RGB images
])

# %%
print(conv_decoder2.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 16384)             507904
#
#  reshape_4 (Reshape)         (None, 16, 16, 64)        0
#
#  conv2d_transpose_8 (Conv2D  (None, 32, 32, 64)        36928
#  Transpose)
#
#  conv2d_transpose_9 (Conv2D  (None, 32, 32, 3)         1731
#  Transpose)
#
# =================================================================
# Total params: 546563 (2.08 MB)
# Trainable params: 546563 (2.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Combining Encoder and decoder to make an autoencoder
conv_ae2=Sequential([conv_encoder2, conv_decoder2])

# %%
conv_ae2.compile(optimizer='nadam', loss='mse')

# %%
conv_ae2.fit(X_train, X_train, epochs=10, validation_data=(X_test, X_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 17s 331us/sample - loss: 0.0274 - val_loss: 0.0192
# Epoch 2/10
# 50000/50000 [==============================] - 14s 283us/sample - loss: 0.0177 - val_loss: 0.0164
# Epoch 3/10
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.0157 - val_loss: 0.0153
# Epoch 4/10
# 50000/50000 [==============================] - 14s 276us/sample - loss: 0.0147 - val_loss: 0.0146
# Epoch 5/10
# 50000/50000 [==============================] - 14s 274us/sample - loss: 0.0140 - val_loss: 0.0139
# Epoch 6/10
# 50000/50000 [==============================] - 14s 274us/sample - loss: 0.0136 - val_loss: 0.0137
# Epoch 7/10
# 50000/50000 [==============================] - 14s 272us/sample - loss: 0.0134 - val_loss: 0.0133
# Epoch 8/10
# 50000/50000 [==============================] - 13s 266us/sample - loss: 0.0132 - val_loss: 0.0136
# Epoch 9/10
# 50000/50000 [==============================] - 13s 262us/sample - loss: 0.0130 - val_loss: 0.0132
# Epoch 10/10
# 50000/50000 [==============================] - 13s 269us/sample - loss: 0.0129 - val_loss: 0.0132

# %%
new_images2 = conv_ae2.predict(X_test)


indices_to_visualize = np.random.choice(len(X_test), size=5, replace=False)


plt.figure(figsize=(15, 5))
for i, idx in enumerate(indices_to_visualize):

    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[idx])
    plt.title('Original')
    plt.axis('off')

    plt.subplot(2, 5, i + 6)
    plt.imshow(new_images2[idx])
    plt.title('new')
    plt.axis('off')

plt.tight_layout()
plt.show()
